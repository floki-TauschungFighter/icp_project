# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('icp_data.csv', encoding='ISO-8859-1', sep=',')
# Out:
# /Users/mengxiangyong/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.rename(columns={'hosp':'num_patients'},inplace=True)

# %%
df.rename(columns={'tx_pos':'positive','tx_incid':'total_positive_rate','TO':'Hospital_occupancy_rate','R':'Virus_infectivity'},inplace=True)

# %%
df.rename(columns={'rea':'num_seriously_ill_patients','rad':'num_cure','dchosp':'num_deaths','incid_hosp':},inplace=True)
# Out:
#       department       date  region label of department  \
# 0              1  2020/3/18      84                 Ain
# 1              1  2020/3/19      84                 Ain
# 2              1  2020/3/20      84                 Ain
# 3              1  2020/3/21      84                 Ain
# 4              1  2020/3/22      84                 Ain
# ...          ...        ...     ...                 ...
# 41001        976  2021/4/23       6             Mayotte
# 41002        976  2021/4/24       6             Mayotte
# 41003        976  2021/4/25       6             Mayotte
# 41004        976  2021/4/26       6             Mayotte
# 41005        976  2021/4/27       6             Mayotte
#
#                label of region  positive  total_positive_rate  \
# 0      Auvergne et Rh_ne-Alpes       NaN                  NaN
# 1      Auvergne et Rh_ne-Alpes       NaN                  NaN
# 2      Auvergne et Rh_ne-Alpes       NaN                  NaN
# ...
